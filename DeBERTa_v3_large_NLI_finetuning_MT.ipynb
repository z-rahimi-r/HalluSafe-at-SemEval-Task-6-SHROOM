# %% [markdown]
# # Installations and Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install transformers
# !pip install accelerate
# !pip install sentencepiece
# !pip install datasets

# %%
from transformers import AutoModel
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import gc
import sentencepiece
from torch.utils.data import Dataset, DataLoader
import re
from tqdm import tqdm
from accelerate import Accelerator
import pickle

import os

# %%
SEED = 1111
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# #Dataset preparation

# %%
import json
with open(f"/content/drive/MyDrive/shroom/val.model-agnostic.json", "r") as outfile:
  val_model_agnostic=json.load(outfile)
print(len(val_model_agnostic))

val_model_agnostic_df=pd.DataFrame(data=val_model_agnostic, columns=["src", "tgt", "hyp", "ref", "task", "model", "labels", "label", "p(Hallucination)"])
val_model_agnostic_df.head(4)
# Out:
# 499
#                                                  src  \
# 0  The writer had just entered into his eighteent...
# 1  Sailors ' and fishermen 's <define> sheath - k...
# 2  As to age , Bead could not form any clear impr...
# 3  Because redpillers are usually normies or <def...
#
#                                                  tgt  \
# 0               Resembling a weasel (in appearance).
# 1                                                  .
# 2               (poetic) An instant, a short moment.
# 3  (incel, _, slang) A man of a slightly lower ra...
#
#                                          hyp  ref task model  \
# 0  Resembling or characteristic of a weasel.  tgt   DM
# 1           Alternative form of sheath knife  tgt   DM
# 2         (obsolete) A short period of time.  tgt   DM
# 3                          (slang) An incel.  tgt   DM
#
#                                               labels              label  \
# 0  [Hallucination, Not Hallucination, Not Halluci...  Not Hallucination
# 1  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 2  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 3  [Not Hallucination, Not Hallucination, Halluci...  Not Hallucination
#
#    p(Hallucination)
# 0               0.2
# 1               0.8
# 2               0.0
# 3               0.2

# %%
with open(f"/content/drive/MyDrive/shroom/val.model-aware.v2.json", "r") as outfile:
  val_model_aware=json.load(outfile)
print(len(val_model_aware))

val_model_aware_df=pd.DataFrame(data=val_model_aware, columns=["src", "tgt", "hyp", "ref", "task", "model", "labels", "label", "p(Hallucination)"])
val_model_aware_df.head(4)
# Out:
# 501
#                                                  src  \
# 0  The sides of the casket were covered with heav...
# 1  Please try not to overreact if she drives badl...
# 2  To prevent spoilage , store in a cool , dry pl...
# 3  The way the opposition has framed the argument...
#
#                                                  tgt  \
# 0  A decorative feature that sits on top of somet...
# 1               To react too much or too intensely .
# 2                          The process of spoiling .
# 3  To construct in words so as to establish a con...
#
#                                                  hyp  ref task  \
# 0                                    A sloping top .  tgt   DM
# 1                                To react too much .  tgt   DM
# 2  The process of spoiling ; the state of being s...  tgt   DM
# 3                   To arrange in a particular way .  tgt   DM
#
#                             model  \
# 0  ltg/flan-t5-definition-en-base
# 1  ltg/flan-t5-definition-en-base
# 2  ltg/flan-t5-definition-en-base
# 3  ltg/flan-t5-definition-en-base
#
#                                               labels              label  \
# 0  [Not Hallucination, Hallucination, Not Halluci...      Hallucination
# 1  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 2  [Hallucination, Not Hallucination, Hallucinati...      Hallucination
# 3  [Hallucination, Not Hallucination, Not Halluci...      Hallucination
#
#    p(Hallucination)
# 0               0.6
# 1               0.0
# 2               0.6
# 3               0.6

# %%
all_val_df=pd.concat((val_model_agnostic_df, val_model_aware_df), ignore_index=True)
all_val_df
# Out:
#                                                    src  \
# 0    The writer had just entered into his eighteent...
# 1    Sailors ' and fishermen 's <define> sheath - k...
# 2    As to age , Bead could not form any clear impr...
# 3    Because redpillers are usually normies or <def...
# 4    On the second day of massive live - fire drill...
# ..                                                 ...
# 995  Doonii fayyadamuun meeshaa geejibuun namootaba...
# 996  وبما أن مونتيفيديو موجودة في جنوب خط الاستواء،...
# 997  Gin-abiabi hiya han Deputy Prime Minister han ...
# 998  འབུ་ཞེས་པའི་ཐ་སྙད་དེ་ཉིད་འབུ་སྲིན་དཔྱད་རིག་པ་བ...
# 999  Ihandjika iyakwece hali kulihana iya kutunguis...
#
#                                                    tgt  \
# 0                 Resembling a weasel (in appearance).
# 1                                                    .
# 2                 (poetic) An instant, a short moment.
# 3    (incel, _, slang) A man of a slightly lower ra...
# 4    An island in Dongyin, Lienchiang, Taiwan, in t...
# ..                                                 ...
# 995  Using ships to transport goods is by far the m...
# 996  Since Montevideo is south of the Equator, it i...
# 997  He was greeted by Singapore's Deputy Prime Min...
# 998  The term bug is used by entomologists in a for...
# 999  Liberal criticism of the reconstruction effort...
#
#                                                    hyp     ref task  \
# 0            Resembling or characteristic of a weasel.     tgt   DM
# 1                     Alternative form of sheath knife     tgt   DM
# 2                   (obsolete) A short period of time.     tgt   DM
# 3                                    (slang) An incel.     tgt   DM
# 4              An island in Lienchiang County, Taiwan.     tgt   DM
# ..                                                 ...     ...  ...
# 995  Using a gas-fired device is a way to stop peop...  either   MT
# 996  Since Montevideo is located south of the equat...  either   MT
# 997  He was also a supporter of Singapore's Deputy ...  either   MT
# 998  The concept of a worm is that the parasitic or...  either   MT
# 999  The only exception to this is the fact that th...  either   MT
#
#                                 model  \
# 0
# 1
# 2
# 3
# 4
# ..                                ...
# 995  facebook/nllb-200-distilled-600M
# 996  facebook/nllb-200-distilled-600M
# 997  facebook/nllb-200-distilled-600M
# 998  facebook/nllb-200-distilled-600M
# 999  facebook/nllb-200-distilled-600M
#
#                                                 labels              label  \
# 0    [Hallucination, Not Hallucination, Not Halluci...  Not Hallucination
# 1    [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 2    [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 3    [Not Hallucination, Not Hallucination, Halluci...  Not Hallucination
# 4    [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# ..                                                 ...                ...
# 995  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 996  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 997  [Hallucination, Hallucination, Not Hallucinati...      Hallucination
# 998  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 999  [Not Hallucination, Not Hallucination, Halluci...  Not Hallucination
#
#      p(Hallucination)
# 0                 0.2
# 1                 0.8
# 2                 0.0
# 3                 0.2
# 4                 0.0
# ..                ...
# 995               1.0
# 996               0.0
# 997               0.8
# 998               1.0
# 999               0.4
#
# [1000 rows x 9 columns]

# %%
all_val_df=all_val_df.sample(frac=1, random_state=42)

# %%
dm_val_df=all_val_df[all_val_df['task']=="DM"]
mt_val_df=all_val_df[all_val_df['task']=="MT"]
pg_val_df=all_val_df[all_val_df['task']=="PG"]

# %%
dm_val_df
# Out:
#                                                    src  \
# 521  Oxygen levels on earth skyrocketed 2.4 billion...
# 660  There they were before us , mother and babe , ...
# 678  Daniel is amazing , wonderful , fantastic , an...
# 626  `` i 've always been a newshound and i was glu...
# 513  [ raoul vaneigem ] i have nothing in common wi...
# ..                                                 ...
# 614  Ye say i played checkers with him -- and -- ''...
# 20                  Cheers <define> marrow </define> !
# 71   so as no fuller on earth can <define> white </...
# 106  The body , however , failed to alter the <defi...
# 102  to <define> misadapt </define> to one 's envir...
#
#                                                    tgt  \
# 521  That which precurses : a forerunner , predeces...
# 660              In an eloquent manner ; stated well .
# 678  An adjective used to praise something exceptio...
# 626                        An investigative reporter .
# 513  Process by which radical or subversive ideas a...
# ..                                                 ...
# 614  While or as if choking , or in such a way as t...
# 20     (Geordie, informal) A friend, pal, buddy, mate.
# 71   (transitive) To make white; to whiten; to bleach.
# 106  (by extension) Characterized by ruthlessly att...
# 102                         To adapt in the wrong way.
#
#                                                    hyp  ref task  \
# 521   Something that is the first stage of a process .  tgt   DM
# 660                            In an eloquent manner .  tgt   DM
# 678  A word or phrase that is more than the usual o...  tgt   DM
# 626  a person who is interested in or devoted to th...  tgt   DM
# 513                 the action of recovering something  tgt   DM
# ..                                                 ...  ...  ...
# 614                              In a choking manner .  tgt   DM
# 20                             (slang) The human body.  tgt   DM
# 71                         (transitive) To make white.  tgt   DM
# 106          (idiomatic) Unconstrained, unadulterated.  tgt   DM
# 102                   (intransitive) To fail to adapt.  tgt   DM
#
#                               model  \
# 521  ltg/flan-t5-definition-en-base
# 660  ltg/flan-t5-definition-en-base
# 678  ltg/flan-t5-definition-en-base
# 626  ltg/flan-t5-definition-en-base
# 513  ltg/flan-t5-definition-en-base
# ..                              ...
# 614  ltg/flan-t5-definition-en-base
# 20
# 71
# 106
# 102
#
#                                                 labels              label  \
# 521  [Hallucination, Not Hallucination, Hallucinati...      Hallucination
# 660  [Hallucination, Not Hallucination, Not Halluci...  Not Hallucination
# 678  [Not Hallucination, Hallucination, Not Halluci...  Not Hallucination
# 626  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 513  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# ..                                                 ...                ...
# 614  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 20   [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 71   [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 106  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 102  [Hallucination, Hallucination, Hallucination, ...      Hallucination
#
#      p(Hallucination)
# 521               0.6
# 660               0.2
# 678               0.4
# 626               0.6
# 513               1.0
# ..                ...
# 614               0.0
# 20                1.0
# 71                0.0
# 106               1.0
# 102               0.8
#
# [375 rows x 9 columns]

# %%
mt_val_df
# Out:
#                                                    src  \
# 411                                Где мне его искать?
# 859  பயணிகள் தங்கள் வீட்டுப் பகுதிகளில் தெரியாத வில...
# 973  Ol 'case' we ol i saspekim H5N1 long Croatia n...
# 938  ٲخرکار، چُھ لیڈرٕیی آسن ٹیمچہ کامیٲبی تہ ناکٲم...
# 899  Kebanyakan teleskop kajian moden merupakan fas...
# ..                                                 ...
# 458  В моей стране люди обычно приветствуют друг др...
# 330  Будем надеяться, в этом году не случится то же...
# 466       Ты действительно думаешь, что я могу летать?
# 860  Moi semellante ao mando a distancia dun televi...
# 435      Мне нравятся люди, которые не боятся стареть.
#
#                                                    tgt  \
# 411                        Where should I look for it?
# 859  Travellers may encounter animal pests that the...
# 973  Suspected cases of H5N1 in Croatia and Denmark...
# 938  After all, the leader is ultimately responsibl...
# 899  Most modern research telescopes are enormous f...
# ..                                                 ...
# 458  People generally greet each other by shaking h...
# 330  Let's hope the same thing doesn't happen this ...
# 466                        You really think I can fly?
# 860  Resembling a television remote, the controller...
# 435      I like people who are not afraid to grow old.
#
#                                                    hyp     ref task  \
# 411                               Where do I want him?  either   MT
# 859  Travelers may encounter insects that destroy u...  either   MT
# 973  In the case of H5N1 in Croatia and Denmark, th...  either   MT
# 938  Finally, leadership is responsible for the suc...  either   MT
# 899  Most modern survey telescopes are large facili...  either   MT
# ..                                                 ...     ...  ...
# 458  In my country, people usually welcome each oth...  either   MT
# 330       Hopefully this year won’t be the same thing.  either   MT
# 466                     Do you really think I can fly?  either   MT
# 860  Much like the remote control of a television, ...  either   MT
# 435            I like people who don’t like to be old.  either   MT
#
#                                 model  \
# 411
# 859  facebook/nllb-200-distilled-600M
# 973  facebook/nllb-200-distilled-600M
# 938  facebook/nllb-200-distilled-600M
# 899  facebook/nllb-200-distilled-600M
# ..                                ...
# 458
# 330
# 466
# 860  facebook/nllb-200-distilled-600M
# 435
#
#                                                 labels              label  \
# 411  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 859  [Hallucination, Hallucination, Hallucination, ...      Hallucination
# 973  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 938  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 899  [Not Hallucination, Hallucination, Not Halluci...  Not Hallucination
# ..                                                 ...                ...
# 458  [Hallucination, Not Hallucination, Not Halluci...  Not Hallucination
# 330  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 466  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 860  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 435  [Hallucination, Hallucination, Hallucination, ...      Hallucination
#
#      p(Hallucination)
# 411               1.0
# 859               1.0
# 973               0.2
# 938               0.0
# 899               0.2
# ..                ...
# 458               0.4
# 330               0.0
# 466               0.0
# 860               0.0
# 435               0.8
#
# [375 rows x 9 columns]

# %%
pg_val_df
# Out:
#                                                    src  \
# 737  But we all know that sadly it does not matter ...
# 740                    We are obliged to him for this.
# 811  There will be other texts on Europol, and Parl...
# 280                    This is not your house anymore.
# 761  At the moment the shipbuilding sector is in ta...
# ..                                                 ...
# 769  Indeed, it is on the agenda for the topical an...
# 308                               Eh, just a few days.
# 214                             I don't question that.
# 700  I would draw attention to the fact that the qu...
# 270                             Something's not right.
#
#                                  tgt  \
# 737
# 740
# 811
# 280     You don't live here anymore.
# 761
# ..                               ...
# 769
# 308           Just a couple of days.
# 214                 I have no doubt.
# 700
# 270  There's something's wrong here.
#
#                                                    hyp     ref task  \
# 737    It doesn't matter if they're in a state or not.     src   PG
# 740                          We have to do it for him.     src   PG
# 811    Parliament will be the colegislator of Europol.     src   PG
# 280                     This isn't your house anymore.  either   PG
# 761  The shipbuilding sector isn't doing well right...     src   PG
# ..                                                 ...     ...  ...
# 769  The debate will take place the day after tomor...     src   PG
# 308                     Uh, just for a couple of days.  either   PG
# 214                            I do not question that.  either   PG
# 700  Questions surrounding Eurostat have been raise...     src   PG
# 270              There's something wrong with me, man.  either   PG
#
#                            model  \
# 737  tuner007/pegasus_paraphrase
# 740  tuner007/pegasus_paraphrase
# 811  tuner007/pegasus_paraphrase
# 280
# 761  tuner007/pegasus_paraphrase
# ..                           ...
# 769  tuner007/pegasus_paraphrase
# 308
# 214
# 700  tuner007/pegasus_paraphrase
# 270
#
#                                                 labels              label  \
# 737  [Not Hallucination, Hallucination, Hallucinati...      Hallucination
# 740  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 811  [Hallucination, Not Hallucination, Hallucinati...  Not Hallucination
# 280  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 761  [Not Hallucination, Hallucination, Not Halluci...  Not Hallucination
# ..                                                 ...                ...
# 769  [Not Hallucination, Not Hallucination, Halluci...  Not Hallucination
# 308  [Hallucination, Not Hallucination, Not Halluci...  Not Hallucination
# 214  [Not Hallucination, Hallucination, Not Halluci...  Not Hallucination
# 700  [Not Hallucination, Not Hallucination, Not Hal...  Not Hallucination
# 270  [Hallucination, Hallucination, Hallucination, ...      Hallucination
#
#      p(Hallucination)
# 737               0.6
# 740               0.2
# 811               0.4
# 280               0.0
# 761               0.4
# ..                ...
# 769               0.4
# 308               0.2
# 214               0.2
# 700               0.0
# 270               0.8
#
# [250 rows x 9 columns]

# %%
val_df=mt_val_df
train_df=pd.concat((dm_val_df, pg_val_df), ignore_index=True)

# %%
gold_labels=[]
first_sentences=[]
second_sentences=[]

for i in tqdm(range(len(train_df))):
  sample=train_df.iloc[i]
  src=sample['src']
  tgt=sample['tgt']
  ref=sample['ref']
  hyp=sample['hyp']
  task=sample['task']
  label=sample['label'].strip().lower()

  if label=="hallucination":
    label="contradiction"
  else:
    label="entailment"

  if task=="MT" or task=="DM":
    sentence1=sample['tgt'].strip().lower()
    sentence2=sample['hyp'].strip().lower()
  else:
    sentence1=sample['src'].strip().lower()
    sentence2=sample['hyp'].strip().lower()

  assert len(sentence1)>0
  assert len(sentence2)>0

  gold_labels.append(label)
  first_sentences.append(sentence1)
  second_sentences.append(sentence2)
# Out:
# 100%|██████████| 625/625 [00:00<00:00, 5927.47it/s]

# %%
temp_dict={
    'gold_label':gold_labels,
    'sentence1':first_sentences,
    'sentence2':second_sentences
}

train_df_part1=pd.DataFrame(data=temp_dict)
train_df_part1.head(3)
# Out:
#       gold_label                                          sentence1  \
# 0  contradiction  that which precurses : a forerunner , predeces...
# 1     entailment              in an eloquent manner ; stated well .
# 2     entailment  an adjective used to praise something exceptio...
#
#                                            sentence2
# 0   something that is the first stage of a process .
# 1                            in an eloquent manner .
# 2  a word or phrase that is more than the usual o...

# %%
gold_labels=[]
first_sentences=[]
second_sentences=[]

for i in tqdm(range(len(val_df))):
  sample=val_df.iloc[i]
  src=sample['src']
  tgt=sample['tgt']
  ref=sample['ref']
  hyp=sample['hyp']
  task=sample['task']
  label=sample['label'].strip().lower()

  if label=="hallucination":
    label="contradiction"
  else:
    label="entailment"

  if task=="MT" or task=="DM":
    sentence1=sample['tgt'].strip().lower()
    sentence2=sample['hyp'].strip().lower()
  else:
    sentence1=sample['src'].strip().lower()
    sentence2=sample['hyp'].strip().lower()

  assert len(sentence1)>0
  assert len(sentence2)>0

  gold_labels.append(label)
  first_sentences.append(sentence1)
  second_sentences.append(sentence2)
# Out:
# 100%|██████████| 375/375 [00:00<00:00, 7064.13it/s]

# %%
temp_dict={
    'gold_label':gold_labels,
    'sentence1':first_sentences,
    'sentence2':second_sentences
}

df_dev=pd.DataFrame(data=temp_dict)
df_dev.head(3)
# Out:
#       gold_label                                          sentence1  \
# 0  contradiction                        where should i look for it?
# 1  contradiction  travellers may encounter animal pests that the...
# 2     entailment  suspected cases of h5n1 in croatia and denmark...
#
#                                            sentence2
# 0                               where do i want him?
# 1  travelers may encounter insects that destroy u...
# 2  in the case of h5n1 in croatia and denmark, th...

# %%
max_sentence_len=100
def trim_sentence(sent):
    try:
        sent = sent.split()
        sent = sent[:max_sentence_len]
        return " ".join(sent)
    except:
        return sent

# %%
train_df_part1['sentence1'] = train_df_part1['sentence1'].apply(trim_sentence)
train_df_part1['sentence2'] = train_df_part1['sentence2'].apply(trim_sentence)
df_dev['sentence1'] = df_dev['sentence1'].apply(trim_sentence)
df_dev['sentence2'] = df_dev['sentence2'].apply(trim_sentence)

train_df_part1 = train_df_part1.loc[train_df_part1['gold_label'].isin(['entailment','contradiction'])]
df_dev = df_dev.loc[df_dev['gold_label'].isin(['entailment','contradiction'])]

print(len(train_df_part1), len(df_dev))
# Out:
# 625 375

# %% [markdown]
# add new labeled data

# %%
path="/content/drive/MyDrive/shroom/our_final_shroom_models/all_3000_labeled_samples.csv"

train_model_agnostic_labeled=pd.read_csv(path)
train_model_agnostic_labeled.head()
# Out:
#                                          src  \
# 0          Не волнуйся. Это только временно.
# 1  Тома никогда нет там, где он должен быть.
# 2               Мне сложно работать с Томом.
# 3                          Воду, пожалуйста.
# 4         Я не ожидал, что Том предаст меня.
#
#                                         tgt  \
# 0         Don't worry. It's only temporary.
# 1   Tom is never where he's supposed to be.
# 2          I have trouble working with Tom.
# 3                      I'd like some water.
# 4  I didn't think that Tom would betray me.
#
#                                   hyp     ref task  label
# 0   Don't worry, it's only temporary.  either   MT      0
# 1    Tom is never where he should be.  either   MT      0
# 2  It's hard for me to work with Tom.  either   MT      0
# 3                      Water, please.  either   MT      0
# 4   I didn't expect Tom to betray me.  either   MT      0

# %%
train_pg=train_model_agnostic_labeled[train_model_agnostic_labeled['task']=="PG"]
train_pg
# Out:
#                                                    src  tgt  \
# 334                          You're not alone, Claire.  NaN
# 335         Who told you to throw acid at Vargas, hmm?  NaN
# 336  Where the pure angel merges with the antic Sphinx  NaN
# 337     Where is it written what is it I'm meant to be  NaN
# 338     We'll find the skipper and then we'll go home.  NaN
# ..                                                 ...  ...
# 662          Violent crimes involving ordinary people.  NaN
# 663                                         Take Ziva.  NaN
# 664                                         Jewellery?  NaN
# 665                                        Hello, Jan.  NaN
# 666                                    I kept my word.  NaN
#
#                                                    hyp  ref task  label
# 334                        You're not alone, claire- -  src   PG      0
# 335        Who told you to throw acid at Vargas, hmmm?  src   PG      0
# 336  ♪ Where the pure angel merges with the antic s...  src   PG      0
# 337    Where is it written what is it I'm meant to be?  src   PG      0
# 338     We'll find the skipper and then we'll go home.  src   PG      0
# ..                                                 ...  ...  ...    ...
# 662         ⁇  crimes involving ordinary human beings.  src   PG      1
# 663                   Take Ziva, take Ziva, take Ziva.  src   PG      1
# 664                                                ⁇ ?  src   PG      1
# 665                                        Hello, Jan.  src   PG      0
# 666                                  I kept my word- -  src   PG      0
#
# [333 rows x 6 columns]

# %%
gold_labels=[]
first_sentences=[]
second_sentences=[]

for i in tqdm(range(len(train_pg))):
  sample=train_pg.iloc[i]
  src=sample['src']
  tgt=sample['tgt']
  ref=sample['ref']
  hyp=sample['hyp']
  task=sample['task']
  label=sample['label']

  if label==1:
    label="contradiction"
  else:
    label="entailment"

  sentence1=src

  if type(sentence1)!=str:
    sentence1=str(sentence1)

  sentence1=sentence1.strip().lower()
  assert len(sentence1)>0

  sentence2=sample["hyp"]

  if type(sentence2)!=str:
    sentence2=str(sentence2)

  sentence2=sentence2.strip().lower()

  assert len(sentence2)>0

  gold_labels.append(label)
  first_sentences.append(sentence1)
  second_sentences.append(sentence2)
# Out:
# 100%|██████████| 333/333 [00:00<00:00, 9013.20it/s]

# %%
train_mt=train_model_agnostic_labeled[train_model_agnostic_labeled['task']=="MT"]
train_mt
# Out:
#                                                     src  \
# 0                     Не волнуйся. Это только временно.
# 1             Тома никогда нет там, где он должен быть.
# 2                          Мне сложно работать с Томом.
# 3                                     Воду, пожалуйста.
# 4                    Я не ожидал, что Том предаст меня.
# ...                                                 ...
# 2995  Одолжи мне бумаги для заметок или что-нибудь в...
# 2996                     Общая тайна доверие формирует.
# 2997  Ты в последнее время сама не своя. Что-то не так?
# 2998       Я бы хотел вернуться в Токио через Гонолулу.
# 2999       Ты понял что-нибудь из того, что Том сказал?
#
#                                                     tgt  \
# 0                     Don't worry. It's only temporary.
# 1               Tom is never where he's supposed to be.
# 2                      I have trouble working with Tom.
# 3                                  I'd like some water.
# 4              I didn't think that Tom would betray me.
# ...                                                 ...
# 2995                   Lend me a memo pad or something.
# 2996                 A secret shared is a trust formed.
# 2997  You haven't been yourself recently. Is somethi...
# 2998          I'd like to return to Tokyo via Honolulu.
# 2999              Did you understand anything Tom said?
#
#                                                  hyp     ref task  label
# 0                  Don't worry, it's only temporary.  either   MT      0
# 1                   Tom is never where he should be.  either   MT      0
# 2                 It's hard for me to work with Tom.  either   MT      0
# 3                                     Water, please.  either   MT      0
# 4                  I didn't expect Tom to betray me.  either   MT      0
# ...                                              ...     ...  ...    ...
# 2995      Let me borrow some notebooks or something.  either   MT      1
# 2996                   A shared secret builds trust.  either   MT      0
# 2997            You've been out of your mind lately.  either   MT      0
# 2998  I'd like to go back to Tokyo through Honolulu.  either   MT      0
# 2999           Did you understand anything Tom said?  either   MT      0
#
# [1334 rows x 6 columns]

# %%
for i in tqdm(range(len(train_mt))):
  sample=train_mt.iloc[i]
  src=sample['src']
  tgt=sample['tgt']
  ref=sample['ref']
  hyp=sample['hyp']
  task=sample['task']
  label=sample['label']

  if label==1:
    label="contradiction"
  else:
    label="entailment"

  sentence1=sample['tgt']

  if type(sentence1)!=str:
    sentence1=str(sentence1)

  sentence1=sentence1.strip().lower()
  assert len(sentence1)>0

  sentence2=sample["hyp"]

  if type(sentence2)!=str:
    sentence2=str(sentence2)

  sentence2=sentence2.strip().lower()

  assert len(sentence2)>0

  gold_labels.append(label)
  first_sentences.append(sentence1)
  second_sentences.append(sentence2)
# Out:
# 100%|██████████| 1334/1334 [00:00<00:00, 9456.07it/s]

# %%
temp_dict={
    'gold_label':gold_labels,
    'sentence1':first_sentences,
    'sentence2':second_sentences
}

df=pd.DataFrame(data=temp_dict)
df
# Out:
#          gold_label                                          sentence1  \
# 0        entailment                          you're not alone, claire.
# 1        entailment         who told you to throw acid at vargas, hmm?
# 2        entailment  where the pure angel merges with the antic sphinx
# 3        entailment     where is it written what is it i'm meant to be
# 4        entailment     we'll find the skipper and then we'll go home.
# ...             ...                                                ...
# 1662  contradiction                   lend me a memo pad or something.
# 1663     entailment                 a secret shared is a trust formed.
# 1664     entailment  you haven't been yourself recently. is somethi...
# 1665     entailment          i'd like to return to tokyo via honolulu.
# 1666     entailment              did you understand anything tom said?
#
#                                               sentence2
# 0                           you're not alone, claire- -
# 1           who told you to throw acid at vargas, hmmm?
# 2     ♪ where the pure angel merges with the antic s...
# 3       where is it written what is it i'm meant to be?
# 4        we'll find the skipper and then we'll go home.
# ...                                                 ...
# 1662         let me borrow some notebooks or something.
# 1663                      a shared secret builds trust.
# 1664               you've been out of your mind lately.
# 1665     i'd like to go back to tokyo through honolulu.
# 1666              did you understand anything tom said?
#
# [1667 rows x 3 columns]

# %%
df['sentence1'] = df['sentence1'].apply(trim_sentence)
df['sentence2'] = df['sentence2'].apply(trim_sentence)

df = df.loc[df['gold_label'].isin(['entailment','contradiction'])]

print(len(df))
# Out:
# 1667

# %%
new_df_train=pd.concat([df, train_df_part1])
new_df_train
# Out:
#         gold_label                                          sentence1  \
# 0       entailment                          you're not alone, claire.
# 1       entailment         who told you to throw acid at vargas, hmm?
# 2       entailment  where the pure angel merges with the antic sphinx
# 3       entailment     where is it written what is it i'm meant to be
# 4       entailment     we'll find the skipper and then we'll go home.
# ..             ...                                                ...
# 620     entailment  indeed, it is on the agenda for the topical an...
# 621     entailment                               eh, just a few days.
# 622     entailment                             i don't question that.
# 623     entailment  i would draw attention to the fact that the qu...
# 624  contradiction                             something's not right.
#
#                                              sentence2
# 0                          you're not alone, claire- -
# 1          who told you to throw acid at vargas, hmmm?
# 2    ♪ where the pure angel merges with the antic s...
# 3      where is it written what is it i'm meant to be?
# 4       we'll find the skipper and then we'll go home.
# ..                                                 ...
# 620  the debate will take place the day after tomor...
# 621                     uh, just for a couple of days.
# 622                            i do not question that.
# 623  questions surrounding eurostat have been raise...
# 624              there's something wrong with me, man.
#
# [2292 rows x 3 columns]

# %%
new_df_train=new_df_train.sample(frac=1, random_state=42)
len(new_df_train)
# Out:
# 2292

# %%
new_df_train.head(2)
# Out:
#       gold_label                                          sentence1  \
# 207   entailment                     at a distance ; disconnected .
# 1414  entailment  fortunately, today tom is much better than he ...
#
#                                               sentence2
# 207    remote ; not confined to a particular location .
# 1414  fortunately, tom is much better today than he ...

# %%
labels_dict={
    "entailment":0,
    'contradiction':1,
}

# %%
def prepare_df(input_df):
  gold_labels=[]
  first_sents=[]
  second_sents=[]

  for i in tqdm(range(len(input_df))):
    sample=input_df.iloc[i]

    sentence1=sample['sentence1']
    sentence2=sample['sentence2']

    if type(sentence1)!=str:
      sentence1=str(sentence1)

    if type(sentence2)!=str:
      sentence2=str(sentence2)

    first_sents.append(sentence1)
    second_sents.append(sentence2)
    gold_labels.append(labels_dict[sample['gold_label']])

  temp_dict={
    'gold_label':gold_labels,
    'sentence1': first_sents,
    'sentence2': second_sents
  }
  df=pd.DataFrame(data=temp_dict)

  return df

# %%
train_df=prepare_df(new_df_train)
dev_df=prepare_df(df_dev)
# Out:
# 100%|██████████| 2292/2292 [00:00<00:00, 16994.62it/s]
# 100%|██████████| 375/375 [00:00<00:00, 18385.53it/s]

# %%
train_df
# Out:
#       gold_label                                          sentence1  \
# 0              0                     at a distance ; disconnected .
# 1              0  fortunately, today tom is much better than he ...
# 2              0                            this peach is a beauty.
# 3              0  having self-respect ; having pride or knowledg...
# 4              0  zugzwang is a situation in which the obligatio...
# ...          ...                                                ...
# 2287           0                            that really shocked me.
# 2288           0                            tom doesn't fear death.
# 2289           0                                 does anybody know?
# 2290           0                                he's afraid of you.
# 2291           0                do you prefer blondes or brunettes?
#
#                                               sentence2
# 0      remote ; not confined to a particular location .
# 1     fortunately, tom is much better today than he ...
# 2                              this peach is beautiful.
# 3     having respect for oneself ; disposed to respe...
# 4     zugzwang is a situation in which the obligatio...
# ...                                                 ...
# 2287                              i was really shocked.
# 2288                        tom is not afraid of death.
# 2289                                  does anyone know?
# 2290                                he's afraid of you.
# 2291              do you prefer a blonde or a brunette?
#
# [2292 rows x 3 columns]

# %%
from transformers import AutoTokenizer, DebertaForSequenceClassification

model_checkpoint=f"/content/drive/MyDrive/shroom/our_final_shroom_models/deberta-v3-large-nli.pt"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

# %%
from datasets import DatasetDict, Dataset

dataset = DatasetDict({'train': Dataset.from_pandas(train_df), 'dev':Dataset.from_pandas(dev_df)})
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['gold_label', 'sentence1', 'sentence2'],
#         num_rows: 2292
#     })
#     dev: Dataset({
#         features: ['gold_label', 'sentence1', 'sentence2'],
#         num_rows: 375
#     })
# })

# %%
max_length = 256

def tokenize_preprocess_function(examples):

    input=tokenizer(examples['sentence1'], examples['sentence2'], max_length=max_length, truncation=True, padding=True, return_tensors="pt")

    data_dict={
        'input_ids': input['input_ids'],
        'label':torch.tensor(examples['gold_label']),
        }

    return data_dict

tokenized_datasets = dataset.map(tokenize_preprocess_function, batched=True)
tokenized_datasets
# Out:
# Map:   0%|          | 0/2292 [00:00<?, ? examples/s]
# Map:   0%|          | 0/375 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['gold_label', 'sentence1', 'sentence2', 'input_ids', 'label'],
#         num_rows: 2292
#     })
#     dev: Dataset({
#         features: ['gold_label', 'sentence1', 'sentence2', 'input_ids', 'label'],
#         num_rows: 375
#     })
# })

# %% [markdown]
# #Huggingface Model and Trainer

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

num_labels=2

model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=num_labels)

# %%
from datasets import load_metric

task="mnli"
metric = load_metric('glue', task)
# Out:
# <ipython-input-38-2fe436dc61b3>:4: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric('glue', task)
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:752: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.16.1/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/1.84k [00:00<?, ?B/s]

# %%
batch_size=8
metric_name = "accuracy"
model_checkpoint = "microsoft/deberta-v3-large"
model_name = model_checkpoint.split("/")[-1]
num_epochs=10

args = TrainingArguments(
    output_dir=f"/content/{model_name}.checkpoint",
    seed=0,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    logging_steps=200,
    weight_decay=0.01,
    load_best_model_at_end=True,
    save_total_limit=2,
    metric_for_best_model=metric_name,
    push_to_hub=False,
    fp16=True
)

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets['dev'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %% [markdown]
# train on mt and pg, eval on mt

# %%
trainer.evaluate()
# Out:
# You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='47' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [47/47 00:04]
#     </div>
# {'eval_loss': 0.07365628331899643,
#  'eval_accuracy': 0.9866666666666667,
#  'eval_runtime': 6.5502,
#  'eval_samples_per_second': 57.25,
#  'eval_steps_per_second': 7.175}

# %%
trainer.train()
# Out:
# You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2870' max='2870' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2870/2870 27:48, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.308600</td>
#       <td>0.210641</td>
#       <td>0.933333</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.247800</td>
#       <td>0.081998</td>
#       <td>0.981333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.123600</td>
#       <td>0.106540</td>
#       <td>0.981333</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.075900</td>
#       <td>0.146022</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019300</td>
#       <td>0.191085</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.010200</td>
#       <td>0.198252</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.015700</td>
#       <td>0.195478</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.015200</td>
#       <td>0.189139</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.016200</td>
#       <td>0.183017</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.003600</td>
#       <td>0.185172</td>
#       <td>0.976000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2870, training_loss=0.07780512139356925, metrics={'train_runtime': 1670.158, 'train_samples_per_second': 13.723, 'train_steps_per_second': 1.718, 'total_flos': 3710968460586960.0, 'train_loss': 0.07780512139356925, 'epoch': 10.0})

# %%
trainer.save_model(f"/content/drive/MyDrive/shroom/{model_name}_MT_best.pt")
